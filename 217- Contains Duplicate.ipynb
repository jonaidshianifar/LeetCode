# %% [markdown]
# # 217 - Contains Duplicate
# <span style="background-color: #04d60f; color: white; padding: 5px 10px; border-radius: 5px; display: inline-block;">
#     Easy
# </span>
#
# Given an integer array nums, return true if any value appears at least twice in the array, and return false if every element is distinct.
#
# [Click here to visit problem page](https://leetcode.com/problems/contains-duplicate/description/)

# %%
def containsDuplicate(nums):
    """
    :type nums: List[int]
    :rtype: bool
    """
    # Create an empty set to store unique values
    unique = set() 
    for num in nums:
        if num in unique:
            # A duplicate is found, so return true
            return True 
        else:
            unique.add(num)

    # No duplicates found, so return false
    return False

# %% [markdown]
# ## Test Case

# %%
containsDuplicate([1,2,3,1])
# Out:
# True

# %%
containsDuplicate([1,2,3,4])
# Out:
# False

# %%
containsDuplicate([1,1,1,3,3,4,3,2,4,2])
# Out:
# True

# %% [markdown]
# ## result
#
# ![result](./results/217.png)
